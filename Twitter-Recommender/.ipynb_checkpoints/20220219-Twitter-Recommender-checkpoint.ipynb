# %%
# pip install SQLAlchemy
# pip install psycopg2
# pip install PyMySQL
# pip install networkx

# %%
# For sending GET requests from the AP
import requests
# For hiding my keys inside a file
from dotenv import load_dotenv
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For creating connection between PostgreSQL & Python
from sqlalchemy import create_engine
import psycopg2
import pymysql
import pandas as pd
import numpy as np
import time
import networkx as nx

# %%
load_dotenv('credentials.env')
Bearer_Token = os.getenv('Bearer_Token')
header = {"Authorization" : "Bearer "+Bearer_Token}

# %%
def get_name(user_id):
    endpoint = "https://api.twitter.com/2/users"
    query = {"ids" : user_id}
    response = requests.request('GET', url = endpoint, headers=header, params = query)
    results = response.json()
    return results['data'][0]['name']

def get_username(user_id):
    endpoint = "https://api.twitter.com/2/users"
    query = {"ids" : user_id}
    response = requests.request('GET', url = endpoint, headers=header, params = query)
    results = response.json()
    return results['data'][0]['username']

# %%
def get_id(username):
    endpoint = "https://api.twitter.com/2/users/by/username/"+username
    response = requests.request('GET', url = endpoint, headers=header)
    results = response.json()
    return results['data']['id']

# %%
# Pegando mais infos do usuário
def get_user_all_infos(user_id):
    endpoint = "https://api.twitter.com/2/users/"+user_id
    query = {"user.fields" : "location", "user.fields" : "created_at", "user.fields" : "public_metrics"}
    response = requests.request('GET', url = endpoint, headers=header, params = query)
    results = response.json()
    return (results['data']['id'],
            results['data']['name'],
            results['data']['username'],
            results['data']['public_metrics']['followers_count'],
            results['data']['public_metrics']['following_count'],
            results['data']['public_metrics']['tweet_count'],
            results['data']['public_metrics']['listed_count'])

# %%
def get_followers_number(user_id):
    endpoint = "https://api.twitter.com/2/users"
    query = {"ids" : user_id, "user.fields" : "public_metrics"}
    response = requests.request('GET', url = endpoint, headers=header, params = query)
    results = response.json()
    return results['data'][0]['public_metrics']['followers_count']

# %%
# Returns a list of all users infos who are followers of the specified user ID
def get_followers(user_id):
    endpoint = "https://api.twitter.com/2/users/"+user_id+"/followers"
    response = requests.request('GET', url = endpoint, headers=header)
    results = response.json()
    try:
        followers_list = [get_user_all_infos(follower['id']) for follower in results['data']]
        return followers_list
    except KeyError:
        return None
    except TypeError:
        return None

followers_dataframe = get_followers(get_id("larabertini"))
print(followers_dataframe)
# Out:
# None

# %%
# Get all the followers at a depth of 2 degrees of connection for a user ID, not counting celebrities
# https://pt.wikipedia.org/wiki/Teoria_dos_seis_graus_de_separa%C3%A7%C3%A3o

def two_degree_followers(user_id):
    users_list = list()
    ids_list = list()
    users_list.extend([get_user_all_infos(user_id)])
    num_followers_uid = get_followers_number(user_id)
    print(num_followers_uid)
    if 0<num_followers_uid<50:
        followers_all_infos = get_followers(user_id)
        print(followers_all_infos)
        if followers_all_infos!=None:
            users_list.extend(followers_all_infos)
            ids_list.extend([(user_id,f_id) for (f_id,f_name,f_username,f_followers_count,f_following_count,f_tweet_count,f_listed_count) in followers_all_infos])
            for first_degree_follower_id in followers_all_infos:
                aux_id = first_degree_follower_id[0]
                num_followers_auid = get_followers_number(aux_id)
                if 0 < num_followers_auid <50:
                    followers_aux_all_infos = get_followers(aux_id)
                    if followers_aux_all_infos!=None:
                        users_list.extend(followers_aux_all_infos)
                        ids_list.extend([(aux_id,f_id) for (f_id,f_name,f_username,f_followers_count,f_following_count,f_tweet_count,f_listed_count) in followers_aux_all_infos])
    return (users_list, ids_list)

two_tree_connections = two_degree_followers(get_id("larabertini"))
# Out:
# 9
# None

# %%
two_tree_connections[0]
# Out:
# [('827216467', 'Lara Bertini Vieira', 'LaraBertini', 9, 55, 28, 0)]

# %%
users_db = pd.DataFrame(two_tree_connections[0])
users_db.columns = ['u_id', 'u_name', 'u_username', 'u_followers_count', 'u_following_count', 'u_tweet_count', 'u_listed_count']
users_db.head()
# Out:
#         u_id               u_name   u_username  u_followers_count  \
# 0  827216467  Lara Bertini Vieira  LaraBertini                  9
#
#    u_following_count  u_tweet_count  u_listed_count
# 0                 55             28               0

# %%
users_db.describe()
# Out:
#        u_followers_count  u_following_count  u_tweet_count  u_listed_count
# count          50.000000          50.000000      50.000000       50.000000
# mean          131.080000         316.120000     702.340000        1.960000
# std           255.208345         433.846566    1590.164163        4.154958
# min             1.000000           2.000000       0.000000        0.000000
# 25%            12.000000          55.750000       9.250000        0.000000
# 50%            30.000000         138.500000      51.000000        0.000000
# 75%            86.500000         335.500000     626.750000        1.000000
# max          1138.000000        1962.000000    8537.000000       15.000000

# %%
ids_db = pd.DataFrame(two_tree_connections[1])
ids_db.columns = ['origin_id', 'following_id']
print(ids_db)
# Out:
#      origin_id         following_id
# 0    827216467            217436563
# 1    827216467            215823703
# 2    827216467             58183547
# 3    827216467             11189402
# 4    827216467            705552870
# 5    827216467            340607650
# 6    827216467           1606817833
# 7    827216467             44011446
# 8    827216467             32215318
# 9    340607650           2667135578
# 10   340607650           2706808941
# 11   340607650           2548312316
# 12   340607650            346542569
# 13  1606817833  1234216847173652480
# 14  1606817833            178197165
# 15  1606817833   882291261629235206
# 16  1606817833           4647978496
# 17  1606817833            364533010
# 18  1606817833            584680262
# 19  1606817833            108570679
# 20  1606817833             22912729
# 21  1606817833            185046901
# 22  1606817833            272414557
# 23  1606817833             65186063
# 24  1606817833           1295307798
# ...

# %%
# Get all the followers at a depth of 3 degrees of connection for a user ID, not counting celebrities
# https://pt.wikipedia.org/wiki/Teoria_dos_seis_graus_de_separa%C3%A7%C3%A3o

def three_degree_followers(user_id):
    users_list = list()
    ids_list = list()
    users_list.extend([get_user_all_infos(user_id)])
    num_followers_uid = get_followers_number(user_id)
    # seguidores diretos
    if 0<num_followers_uid<100:
        first_followers_all_infos = get_followers(user_id)
        if first_followers_all_infos!=None:
            users_list.extend(first_followers_all_infos)
            ids_list.extend([(user_id,f_id) for (f_id,f_name,f_username,f_followers_count,f_following_count,f_tweet_count,f_listed_count) in first_followers_all_infos])
            time.sleep(60*15)
            for first_degree_follower in first_followers_all_infos:
                first_degree_follower_id = first_degree_follower[0]
                num_followers_fist_degree = get_followers_number(first_degree_follower_id)
                # seguidores dos usuários do meu primeiro nível de conexão
                if 0 < num_followers_fist_degree <100:
                    followers_first_degree_all_infos = get_followers(first_degree_follower_id)
                    if followers_first_degree_all_infos!=None:
                        users_list.extend(followers_first_degree_all_infos)
                        ids_list.extend([(first_degree_follower_id,f_id) for (f_id,f_name,f_username,f_followers_count,f_following_count,f_tweet_count,f_listed_count) in followers_first_degree_all_infos])
                        time.sleep(60*15)
                        for second_degree_follower in first_followers_all_infos:
                            second_degree_follower_id = second_degree_follower[0]
                            num_followers_second_degree = get_followers_number(second_degree_follower_id)
                            # seguidores dos usuários do meu segundo nível de conexão
                            if 0 < num_followers_second_degree <100:
                                followers_second_degree_all_infos = get_followers(second_degree_follower_id)
                                if followers_second_degree_all_infos!=None:
                                    users_list.extend(followers_second_degree_all_infos)
                                    ids_list.extend([(second_degree_follower_id,f_id) for (f_id,f_name,f_username,f_followers_count,f_following_count,f_tweet_count,f_listed_count) in followers_second_degree_all_infos])
                                    time.sleep(60*15)
                                    for third_degree_follower in followers_second_degree_all_infos:
                                        third_degree_follower_id = third_degree_follower[0]
                                        num_followers_third_degree = get_followers_number(third_degree_follower_id)
                                        # seguidores dos usuários do meu segundo nível de conexão
                                        if 0 < num_followers_third_degree <100:
                                            followers_third_degree_all_infos = get_followers(third_degree_follower_id)
                                            if followers_third_degree_all_infos!=None:
                                                users_list.extend(followers_third_degree_all_infos)
                                                ids_list.extend([(third_degree_follower_id,f_id) for (f_id,f_name,f_username,f_followers_count,f_following_count,f_tweet_count,f_listed_count) in followers_third_degree_all_infos])
                                                time.sleep(60*15)
    return (users_list, ids_list)

three_tree_connections = three_degree_followers(get_id("larabertini"))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\envs\Python3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\envs\Python3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda3\envs\Python3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
users_db_three_tree = pd.DataFrame(three_tree_connections[0])
users_db_three_tree.columns = ['u_id', 'u_name', 'u_username', 'u_followers_count', 'u_following_count', 'u_tweet_count', 'u_listed_count']
users_db_three_tree = users_db_three_tree.drop_duplicates(subset=['u_id'])
users_db_three_tree
# Out:
#                    u_id                                      u_name  \
# 0             827216467                         Lara Bertini Vieira
# 1             217436563                                Marcio Mello
# 2             215823703                             Jhonatan Casale
# 3              58183547                               Elisa Posptar
# 4              11189402                                 Elisa Gomes
# 5             705552870                                Luis Mariano
# 6             340607650                                Luis Pereira
# 7            1606817833                             Luciano Dellier
# 8              44011446                            spacerossi.eth 🔮
# 9              32215318                                     Hamed S
# 10           2667135578                             Eazy Cosméticos
# 11           2706808941                                Joyce Paixao
# 12           2548312316                          Angela Salinas RC♥
# ...

# %%
users_db_three_tree.describe()
# Out:
#        u_followers_count  u_following_count  u_tweet_count  u_listed_count
# count          54.000000          54.000000      54.000000       54.000000
# mean          144.037037         331.962963     723.518519        2.111111
# std           272.711954         438.038508    1531.983149        4.394107
# min             1.000000           2.000000       0.000000        0.000000
# 25%            12.500000          62.500000      10.000000        0.000000
# 50%            30.000000         138.500000      87.000000        0.000000
# 75%            89.250000         367.250000     825.750000        1.000000
# max          1138.000000        1962.000000    8537.000000       15.000000

# %%
ids_db_three_tree = pd.DataFrame(three_tree_connections[1])
ids_db_three_tree.columns = ['origin_id', 'following_id']
print(ids_db_three_tree)
# Out:
#      origin_id following_id
# 0    827216467    217436563
# 1    827216467    215823703
# 2    827216467     58183547
# 3    827216467     11189402
# 4    827216467    705552870
# ..         ...          ...
# 164   32215318     73273120
# 165   32215318     62894774
# 166   32215318     63919217
# 167   32215318     62928029
# 168   32215318     49671107
#
# [169 rows x 2 columns]

# %%
number_connections = ids_db_three_tree.groupby(['origin_id']).count()

# %%
print(number_connections)
# Out:
#             following_id
# origin_id
# 1606817833            48
# 32215318              96
# 340607650             16
# 827216467              9

# %%
users_db_three_tree = pd.merge(users_db_three_tree,number_connections,left_on='u_id',right_on='origin_id')

# %%
print(users_db_three_tree)
# Out:
#          u_id               u_name      u_username  u_followers_count  \
# 0   827216467  Lara Bertini Vieira     LaraBertini                  9
# 1   340607650         Luis Pereira     pereira_lui                  4
# 2  1606817833      Luciano Dellier  lucianodellier                 12
# 3    32215318              Hamed S       hshalileh                 24
#
#    u_following_count  u_tweet_count  u_listed_count  following_id
# 0                 55             28               0             9
# 1                 24              5               0            16
# 2                 58             10               0            48
# 3                 91              7               0            96

# %%
# Connecting Python & PostgreSQL
engine = create_engine('postgresql+psycopg2://postgres:root@localhost:5432/ironhack')
print(engine)
sql_connection = engine.connect()
print(sql_connection)
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/ironhack)
# ...

# %%
users_db_three_tree.to_sql(name="users", con=sql_connection, if_exists="append", index=False, schema="twitter_recommender")

# %%
ids_db.to_sql(name="user_followers", con=sql_connection, if_exists="append", index=True, schema="twitter_recommender", index_label="relationship_id")

# %%
G_2 = nx.Graph()
G_2.add_nodes_from(two_tree_connections[0])
G_2.add_edges_from(two_tree_connections[1])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22496/3833865388.py in <module>
# ----> 1 two_tree_connections[1]
#
# NameError: name 'two_tree_connections' is not defined

# %%
nx.draw(G_2)

# %%
nx.diameter(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24736/2541282540.py in <module>
# ----> 1 nx.diameter(G)
#
# ~\anaconda3\envs\Python3\lib\site-packages\networkx\algorithms\distance_measures.py in diameter(G, e, usebounds)
#     297         return extrema_bounding(G, compute="diameter")
#     298     if e is None:
# --> 299         e = eccentricity(G)
#     300     return max(e.values())
#     301
#
# ~\anaconda3\envs\Python3\lib\site-packages\networkx\algorithms\distance_measures.py in eccentricity(G, v, sp)
#     262             else:
#     263                 msg = "Found infinite path length because the graph is not" " connected"
# --> 264             raise nx.NetworkXError(msg)
#     265
#     266         e[n] = max(length.values())
#
# NetworkXError: Found infinite path length because the graph is not connected

# %%
nx.numeric_assortativity_coefficient(G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24736/381696869.py in <module>
# ----> 1 nx.numeric_assortativity_coefficient(G)
#
# TypeError: numeric_assortativity_coefficient() missing 1 required positional argument: 'attribute'

# %%
G_3 = nx.Graph()
G_3.add_nodes_from(list(users_db_three_tree))
G_3.add_edges_from(three_tree_connections[1])

# %%
nx.draw(G_3)

# %%
list(users_db_three_tree)
# Out:
# ['u_id',
#  'u_name',
#  'u_username',
#  'u_followers_count',
#  'u_following_count',
#  'u_tweet_count',
#  'u_listed_count',
#  'following_id']

# %%
list(users_db_three_tree['u_id'])
# Out:
# ['827216467', '340607650', '1606817833', '32215318']

# %%
# nx.connected_component_subgraphs

# %%
# Dúvidas:
# Pq o grafo não está conectado?

# %%
# inner join para tirar usuários privados
# contador para somar 900 chamadas >> só chama o sleep depois que o contador tiver > 600, por exemplo
